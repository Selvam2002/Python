# %%
1. Total no of Passengers
2. No of alive Passenger
3. No of dead Passenger 
4. Total Fare Price 
5. Gender based Classification 
6. Passenger by class 
7. Survival & died percentage
8. Survive by gender 
9. Died by Gender 
10 Passenger based on Age Group

# %%
import numpy as np

import pandas as pd

import csv

import matplotlib.pyplot as plt

import seaborn as sns

# %%
titanic=pd.read_csv("Titanic Dataset.csv")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       Unnamed: 3     sex      age  sibsp  parch  ticket      fare embarked
# ...

# %%
total=titanic.shape[0]
print('Total no of passengers:',total)

survival=titanic['survived'].value_counts()
print("\nNo of alive passenger:",survival[1])

dead=titanic['survived'].value_counts()
print("\nNo of dead passenger:",dead[0])

Total_fare=titanic['fare'].sum()
print("\nTotal fare:",Total_fare)
# Out:
# Total no of passengers: 1309
#
# No of alive passenger: 500
#
# No of dead passenger: 809
#
# Total fare: 43550.4869

# %%
file=titanic['sex'].value_counts()
plt.figure(figsize=(5,5))


plt.pie(file,labels=file.index,autopct='%0.1f%%',explode=(0,0.05),startangle=90,colors=['skyblue', 'yellow'],shadow=True)
plt.title('Gender based Classification', bbox={'facecolor':'0.8'})
plt.legend(['Male','Female'],loc='upper right',bbox_to_anchor=(1.25, 1))

plt.show()

# %%
p_class=titanic['pclass'].value_counts()
print(p_class)

plt.figure(figsize=(5,5))

ax=plt.axes()
ax.set_facecolor('skyblue')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 1), va='bottom' if yval < 5 else 'top', ha='center', color='black', fontsize=10)

plt.bar(p_class.index, p_class.values, color=['red'])
plt.xlabel('p_class')
plt.ylabel('Count')
plt.title('Passenger by class',bbox={'facecolor':'0.8'})

plt.show()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
z=titanic['survived'].value_counts()
print(z)

plt.figure(figsize=(5,5))

plt.pie(data,startangle=90,labels=[z[0],z[1]],autopct='%0.1f%%',colors=["orange","pink"],explode=(0,0.02),shadow=True)
plt.title('Survived & died percentage%',bbox={'facecolor':'0.8'})
plt.legend(["survived","died"],bbox_to_anchor=(1.25,1))
plt.show()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
plt.figure(figsize=(5,5))
x=sns.countplot(titanic,x=titanic["sex"],hue="survived")

for i in x.containers:
 x.bar_label(i)
plt.title("Survival and dead by gender")
plt.show()

# %%
plt.figure(figsize=(4,5))
a=sns.countplot(titanic,x=titanic['pclass'])
for i in a.containers:
 a.bar_label(i)
plt.title('Passengers by class')
plt.show()

# %%
a=titanic['age'].dropna()

child=a[a<=12].count()
teenagers=a[(a>12) & (a<=19)].count()
adults=a[(a>19) & (a<=60)].count()
senior_citizens=a[a>60].count()

x = ["Child"+'('+str(child)+')', "Teenagers"+'('+str(teenagers)+')', 
"Adults"+'('+str(adults)+')', 
"senior_citizens"+'('+str(senior_citizens)+')']
y = [child, teenagers, adults, senior_citizens]

plt.bar(x,y,color=['orange'])
plt.title('Passenger based on Age Group')
plt.show()
